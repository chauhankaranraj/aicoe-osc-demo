# %% [markdown]
# # 1. Table extraction

# %%
import pdb
import pathlib
import logging

import numpy as np

from pdf2image import convert_from_path, pdfinfo_from_path
from mmdet.apis import init_detector, inference_detector, show_result_pyplot

from src.components import config
from src.components.preprocessing import PDFTableExtractor

logger = logging.getLogger()
logger.setLevel(logging.ERROR)

# %%
# set file paths
CONFIG_FOLDER = pathlib.Path('./config').resolve()
CHECKPOINT_FOLDER = pathlib.Path('../../models/checkpoint').resolve()
DATA_FOLDER = pathlib.Path('../../data').resolve()

# %%
# table extractor args
PDFTableExtractor_kwargs = {
    "batch_size": -1,
    "cscdtabnet_config": CONFIG_FOLDER / "cascade_mask_rcnn_hrnetv2p_w32_20e.py",  # if original is used then open-mmlab/mmdetection#4397
    "cscdtabnet_ckpt": CHECKPOINT_FOLDER / "icdar_19b2.pth",  # _v2 loads fine but otherwise doesnt
    "bbox_thres": .85,
    "dpi": 200
}

# %%
# init extractor
table_extractor = PDFTableExtractor(**PDFTableExtractor_kwargs)
# Out:
# /home/kachau/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/models/builder.py:51: UserWarning: train_cfg and test_cfg is deprecated, please specify them in model
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmcv/utils/registry.py in build_from_cfg(cfg, registry, default_args)
#      51     try:
# ---> 52         return obj_cls(**args)
#      53     except Exception as e:
#
# TypeError: __init__() got an unexpected keyword argument 'num_stages'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5858/4074044873.py in <module>
#       1 # init extractor
# ----> 2 table_extractor = PDFTableExtractor(**PDFTableExtractor_kwargs)
#
# ~/Documents/diffbranch/aicoe-osc-demo/src/components/preprocessing/pdf_table_extractor.py in __init__(self, batch_size, cscdtabnet_config, cscdtabnet_ckpt, bbox_thres, dpi, name)
#      47         self.bbox_thres = bbox_thres
#      48         self.dpi = dpi
# ---> 49         self.model = self.__create_model()
#      50
#      51     def __create_model(self):
#
# ~/Documents/diffbranch/aicoe-osc-demo/src/components/preprocessing/pdf_table_extractor.py in __create_model(self)
#      72         while not download_successful:
#      73             try:
# ---> 74                 det = init_detector(
#      75                     self.cscdtabnet_config, self.cscdtabnet_ckpt, device=device
#      76                 )
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/apis/inference.py in init_detector(config, checkpoint, device, cfg_options)
#      38     config.model.pretrained = None
#      39     config.model.train_cfg = None
# ---> 40     model = build_detector(config.model, test_cfg=config.get('test_cfg'))
#      41     if checkpoint is not None:
#      42         map_loc = 'cpu' if device == 'cpu' else None
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/models/builder.py in build_detector(cfg, train_cfg, test_cfg)
#      56     assert cfg.get('test_cfg') is None or test_cfg is None, \
#      57         'test_cfg specified in both outer field and model field '
# ---> 58     return DETECTORS.build(
#      59         cfg, default_args=dict(train_cfg=train_cfg, test_cfg=test_cfg))
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmcv/utils/registry.py in build(self, *args, **kwargs)
#     210
#     211     def build(self, *args, **kwargs):
# --> 212         return self.build_func(*args, **kwargs, registry=self)
#     213
#     214     def _add_children(self, registry):
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmcv/cnn/builder.py in build_model_from_cfg(cfg, registry, default_args)
#      25         return Sequential(*modules)
#      26     else:
# ---> 27         return build_from_cfg(cfg, registry, default_args)
#      28
#      29
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmcv/utils/registry.py in build_from_cfg(cfg, registry, default_args)
#      53     except Exception as e:
#      54         # Normal TypeError does not print class name.
# ---> 55         raise type(e)(f'{obj_cls.__name__}: {e}')
#      56
#      57
#
# TypeError: CascadeRCNN: __init__() got an unexpected keyword argument 'num_stages'

# %% [markdown]
# ### Extract tables from a single pdf file
# Table Extraction happens in two stages:
# 1. **Infer Bounding Box:** Convert a pdf into image and use an object detection model for table recognition. The model is called CascadeTabNet. The output of this stage is the coordinates of tables.
#
# 2. **Extract tables:** from PDFs using Tabula. The coordinates are passed to tabula for analyzing that area of page.

# %%
# sample data
pdf_path = DATA_FOLDER / "pdfs/ESG/sustainability-report-2019.pdf"
pdf_path
# Out:
# PosixPath('/home/kachau/Documents/diffbranch/aicoe-osc-demo/data/pdfs/ESG/sustainability-report-2019.pdf')

# %% [markdown]
# ### 1. Infer Bounding Box

# %%
# convert from pdf to sequence of images
images = convert_from_path(
    pdf_path,
    first_page=1,
    last_page=20,
    use_pdftocairo=True,
    dpi=PDFTableExtractor_kwargs["dpi"],
)

# verify it converted correctly
page_num = 3
images[page_num]
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=3308x2339 at 0x7FB870065C40>

# %%
# pdb.set_trace().
temp = inference_detector(table_extractor.model, np.array(images[page_num]))
# Out:
# /home/kachau/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/datasets/utils.py:65: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(
# /home/kachau/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/torch/nn/functional.py:3609: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   warnings.warn(
# /home/kachau/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/core/anchor/anchor_generator.py:324: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# /home/kachau/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/core/anchor/anchor_generator.py:360: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5858/2691908971.py in <module>
#       1 # pdb.set_trace().
# ----> 2 temp = inference_detector(table_extractor.model, np.array(images[page_num]))
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/apis/inference.py in inference_detector(model, imgs)
#     146     # forward the model
#     147     with torch.no_grad():
# --> 148         results = model(return_loss=False, rescale=True, **data)
#     149
#     150     if not is_batch:
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmcv/runner/fp16_utils.py in new_func(*args, **kwargs)
#      96                                 'method of nn.Module')
#      97             if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# ---> 98                 return old_func(*args, **kwargs)
#      99
#     100             # get the arg spec of the decorated method
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/models/detectors/base.py in forward(self, img, img_metas, return_loss, **kwargs)
#     172             return self.forward_train(img, img_metas, **kwargs)
#     173         else:
# --> 174             return self.forward_test(img, img_metas, **kwargs)
#     175
#     176     def _parse_losses(self, losses):
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/models/detectors/base.py in forward_test(self, imgs, img_metas, **kwargs)
#     145             if 'proposals' in kwargs:
#     146                 kwargs['proposals'] = kwargs['proposals'][0]
# --> 147             return self.simple_test(imgs[0], img_metas[0], **kwargs)
#     148         else:
#     149             assert imgs[0].size(0) == 1, 'aug test does not support ' \
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/models/detectors/two_stage.py in simple_test(self, img, img_metas, proposals, rescale)
#     176         x = self.extract_feat(img)
#     177         if proposals is None:
# --> 178             proposal_list = self.rpn_head.simple_test_rpn(x, img_metas)
#     179         else:
#     180             proposal_list = proposals
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/models/dense_heads/dense_test_mixins.py in simple_test_rpn(self, x, img_metas)
#     123         """
#     124         rpn_outs = self(x)
# --> 125         proposal_list = self.get_bboxes(*rpn_outs, img_metas)
#     126         return proposal_list
#     127
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmcv/runner/fp16_utils.py in new_func(*args, **kwargs)
#     184                                 'method of nn.Module')
#     185             if not (hasattr(args[0], 'fp16_enabled') and args[0].fp16_enabled):
# --> 186                 return old_func(*args, **kwargs)
#     187             # get the arg spec of the decorated method
#     188             args_info = getfullargspec(old_func)
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/models/dense_heads/rpn_head.py in get_bboxes(self, cls_scores, bbox_preds, img_metas, cfg, rescale, with_nms)
#     150             img_shape = img_metas[img_id]['img_shape']
#     151             scale_factor = img_metas[img_id]['scale_factor']
# --> 152             proposals = self._get_bboxes_single(cls_score_list, bbox_pred_list,
#     153                                                 mlvl_anchors, img_shape,
#     154                                                 scale_factor, cfg, rescale)
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmdet/models/dense_heads/rpn_head.py in _get_bboxes_single(self, cls_scores, bbox_preds, mlvl_anchors, img_shape, scale_factor, cfg, rescale)
#     242                 ids = ids[valid_mask]
#     243         if proposals.numel() > 0:
# --> 244             dets, keep = batched_nms(proposals, scores, ids, cfg.nms)
#     245         else:
#     246             return proposals.new_zeros(0, 5)
#
# ~/.local/share/virtualenvs/aicoe-osc-demo-QlLYP2u9/lib/python3.8/site-packages/mmcv/utils/config.py in __getattr__(self, name)
#      46         else:
#      47             return value
# ---> 48         raise ex
#      49
#      50
#
# AttributeError: 'ConfigDict' object has no attribute 'nms'

# %%
print ("Coordinates and probabilities of bordered tables\n", (temp[0][0]))
print ("Coordinates and probabilities of borderless tables\n", (temp[0][2]))
# Out:
# Coordinates and probabilities of bordered tables
#  []
# Coordinates and probabilities of borderless tables
#  [[1.18381516e+02 2.91443512e+02 1.57741553e+03 6.94924866e+02
#   9.98581409e-01]
#  [1.40852097e+02 9.03176086e+02 1.85584314e+03 9.85421814e+02
#   2.33963147e-01]]

# %%
show_result_pyplot(
    np.array(images[page_num]), 
    temp,
    ('Bordered', 'cell', 'Borderless'), 
    score_thr=PDFTableExtractor_kwargs["bbox_thres"]
)

# %% [markdown]
# These steps are encapsulated in a single function in PDFTableExtractor, `infer_bbox()`

# %%
# Infer bbox for each page
table_coords = table_extractor.infer_bbox(pdf_path)
# Out:
# Page:   0%|          | 0/21 [00:00<?, ?it/s]
# Inferring tables for page 1-21:   0%|          | 0/20 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:2506: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
#
# Inferring tables for page 1-21:   5%|▌         | 1/20 [00:00<00:08,  2.13it/s]
# Inferring tables for page 1-21:  10%|█         | 2/20 [00:00<00:08,  2.07it/s]
# Inferring tables for page 1-21:  15%|█▌        | 3/20 [00:01<00:09,  1.73it/s]
# Inferring tables for page 1-21:  20%|██        | 4/20 [00:02<00:08,  1.78it/s]
# Inferring tables for page 1-21:  25%|██▌       | 5/20 [00:02<00:07,  2.00it/s]
# Inferring tables for page 1-21:  30%|███       | 6/20 [00:03<00:06,  2.18it/s]
# Inferring tables for page 1-21:  35%|███▌      | 7/20 [00:03<00:05,  2.32it/s]
# Inferring tables for page 1-21:  40%|████      | 8/20 [00:03<00:04,  2.77it/s]
# Inferring tables for page 1-21:  45%|████▌     | 9/20 [00:04<00:04,  2.32it/s]
# Inferring tables for page 1-21:  50%|█████     | 10/20 [00:04<00:04,  2.47it/s]
# Inferring tables for page 1-21:  55%|█████▌    | 11/20 [00:05<00:04,  2.00it/s]
# Inferring tables for page 1-21:  60%|██████    | 12/20 [00:05<00:04,  1.76it/s]
# Inferring tables for page 1-21:  65%|██████▌   | 13/20 [00:06<00:04,  1.48it/s]
# Inferring tables for page 1-21:  70%|███████   | 14/20 [00:08<00:05,  1.08it/s]
# Inferring tables for page 1-21:  75%|███████▌  | 15/20 [00:09<00:04,  1.03it/s]
# Inferring tables for page 1-21:  80%|████████  | 16/20 [00:10<00:03,  1.11it/s]
# Inferring tables for page 1-21:  85%|████████▌ | 17/20 [00:12<00:03,  1.24s/it]
# Inferring tables for page 1-21:  90%|█████████ | 18/20 [00:14<00:02,  1.42s/it]
# Inferring tables for page 1-21:  95%|█████████▌| 19/20 [00:15<00:01,  1.53s/it]
# Inferring tables for page 1-21: 100%|██████████| 20/20 [00:17<00:00,  1.16it/s]
# Page:  95%|█████████▌| 20/21 [00:32<00:01,  1.65s/it]
# Inferring tables for page 21-41: 0it [00:00, ?it/s]
# Page: 40it [00:50,  1.16s/it]

# %% [markdown]
# ### 2. Extract Table using Tabula

# %% [markdown]
# `extract_table()` extracts tables using Tabula and saves them as csv in the extraction folder

# %%
tables, tables_meta = table_extractor.extract_table(pdf_path, table_coords, config.EXTRACTION_FOLDER, None)
# Out:
# Extracting and saving tables:   0%|          | 0/19 [00:00<?, ?it/s]
# Extracting and saving tables:   5%|▌         | 1/19 [00:01<00:24,  1.36s/it]
# Extracting and saving tables:  11%|█         | 2/19 [00:02<00:23,  1.36s/it]
# Extracting and saving tables:  16%|█▌        | 3/19 [00:05<00:28,  1.78s/it]
# Extracting and saving tables:  21%|██        | 4/19 [00:06<00:24,  1.66s/it]
# Extracting and saving tables:  26%|██▋       | 5/19 [00:08<00:21,  1.57s/it]
# Extracting and saving tables:  32%|███▏      | 6/19 [00:09<00:19,  1.51s/it]
# Extracting and saving tables:  37%|███▋      | 7/19 [00:10<00:17,  1.45s/it]
# Extracting and saving tables:  42%|████▏     | 8/19 [00:13<00:19,  1.81s/it]
# Extracting and saving tables:  47%|████▋     | 9/19 [00:14<00:16,  1.69s/it]
# Extracting and saving tables:  53%|█████▎    | 10/19 [00:18<00:21,  2.37s/it]
# Extracting and saving tables:  58%|█████▊    | 11/19 [00:23<00:23,  2.89s/it]
# Extracting and saving tables:  63%|██████▎   | 12/19 [00:26<00:20,  2.92s/it]
# Extracting and saving tables:  68%|██████▊   | 13/19 [00:27<00:14,  2.47s/it]
# Extracting and saving tables:  74%|███████▎  | 14/19 [00:28<00:10,  2.18s/it]
# Extracting and saving tables:  79%|███████▉  | 15/19 [00:31<00:09,  2.37s/it]
# Extracting and saving tables:  84%|████████▍ | 16/19 [00:38<00:11,  3.70s/it]
# Extracting and saving tables:  89%|████████▉ | 17/19 [00:39<00:06,  3.00s/it]
# Extracting and saving tables:  95%|█████████▍| 18/19 [00:42<00:02,  2.89s/it]
# Extracting and saving tables: 100%|██████████| 19/19 [00:46<00:00,  2.46s/it]

# %%
tables[page_num+1][0]
# Out:
#                                         0        1        2     3
# 0                                 [PLN m]  Q1 2019  Q1 2018   y/y
# 1                                  EBITDA    1 889    2 214  -15%
# 2                                    EBIT      950    1 315  -28%
# 3                    Net profit to equity      585      935  -37%
# 4  Net profit to equity – ex. Impairments      604      969  -38%
# 5                                     EPS     0.31     0.50  -38%
# 6                   EPS – ex. Impairments     0.32     0.52  -38%

# %%
# !ls $config.EXTRACTION_FOLDER
# Out:
# final_combined_page10_1.csv  final_combined_page17_5.csv
# final_combined_page11_1.csv  final_combined_page18_1.csv
# final_combined_page11_2.csv  final_combined_page19_1.csv
# final_combined_page11_3.csv  final_combined_page19_2.csv
# final_combined_page12_1.csv  final_combined_page1_1.csv
# final_combined_page12_2.csv  final_combined_page20_1.csv
# final_combined_page12_3.csv  final_combined_page20_2.csv
# final_combined_page13_1.csv  final_combined_page20_3.csv
# final_combined_page13_2.csv  final_combined_page2_1.csv
# final_combined_page14_1.csv  final_combined_page3_1.csv
# final_combined_page15_1.csv  final_combined_page3_2.csv
# final_combined_page16_1.csv  final_combined_page4_1.csv
# final_combined_page16_2.csv  final_combined_page6_1.csv
# final_combined_page17_1.csv  final_combined_page7_1.csv
# final_combined_page17_2.csv  final_combined_page8_1.csv
# final_combined_page17_3.csv  final_combined_page9_1.csv
# final_combined_page17_4.csv  final_combined_page9_2.csv

# %% [markdown]
# ## Automate these processes using run_folder() function

# %% [markdown]
# We extract all tables from pdfs in the `data/pdfs` folder. First, let's delete all files in the extraction folder. In the pdfs folder, we have both `2015_BASF_Report.pdf` and `cez-annual-report-2018.pdf`.

# %%
# !rm -rf $config.EXTRACTION_FOLDER/*

# %%
# !ls $config.EXTRACTION_FOLDER

# %% [markdown]
# This whole process will take approximately 15-20min due to

# %%
table_extractor.run_folder(config.PDF_FOLDER, config.EXTRACTION_FOLDER)
# Out:
# 2020-07-23 21:50:57,352 — esg_data_pipeline.components.pdf_table_extractor — INFO —run:221 — PDFTableExtractor is running on file /esg_data_pipeline/esg_data_pipeline/data/pdfs/cez-en-annual-report-2018.pdf...
# Page:   0%|          | 0/9 [00:00<?, ?it/s]
#
#
# Inferring tables for page 1-9:   0%|          | 0/8 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:2506: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
#
#
#
# Inferring tables for page 1-9:  12%|█▎        | 1/8 [00:00<00:01,  5.72it/s]
#
#
# Inferring tables for page 1-9:  25%|██▌       | 2/8 [00:00<00:01,  4.42it/s]
#
#
# Inferring tables for page 1-9:  38%|███▊      | 3/8 [00:00<00:01,  4.79it/s]
#
#
# Inferring tables for page 1-9:  50%|█████     | 4/8 [00:00<00:00,  4.72it/s]
#
#
# Inferring tables for page 1-9:  62%|██████▎   | 5/8 [00:01<00:00,  4.79it/s]
#
#
# Inferring tables for page 1-9:  75%|███████▌  | 6/8 [00:01<00:00,  4.98it/s]
#
#
# Inferring tables for page 1-9:  88%|████████▊ | 7/8 [00:02<00:00,  2.81it/s]
#
#
# Inferring tables for page 1-9: 100%|██████████| 8/8 [00:02<00:00,  3.24it/s]
#
#
# Page:  89%|████████▉ | 8/9 [00:07<00:00,  1.00it/s]
#
#
# Inferring tables for page 9-17: 0it [00:00, ?it/s]
#
#
# Page: 16it [00:08,  1.42it/s]
#
#
# Extracting and saving tables:   0%|          | 0/3 [00:00<?, ?it/s]
#
#
# Extracting and saving tables:  33%|███▎      | 1/3 [00:00<00:01,  1.35it/s]
#
#
# Extracting and saving tables:  67%|██████▋   | 2/3 [00:03<00:01,  1.46s/it]
#
#
# Extracting and saving tables: 100%|██████████| 3/3 [00:05<00:00,  1.67s/it]
# 2020-07-23 21:51:10,519 — esg_data_pipeline.components.pdf_table_extractor — INFO —run:221 — PDFTableExtractor is running on file /esg_data_pipeline/esg_data_pipeline/data/pdfs/2015_BASF_Report.pdf...
# Page:   0%|          | 0/263 [00:00<?, ?it/s]
#
# Page: 16it [00:26,  1.42it/s]
#
#
#
# Inferring tables for page 1-263:   0%|          | 0/262 [00:00<?, ?it/s]/opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:2506: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
#
#
#
#
# Inferring tables for page 1-263:   0%|          | 1/262 [00:00<01:07,  3.89it/s]
#
#
#
# Inferring tables for page 1-263:   1%|          | 2/262 [00:01<02:37,  1.65it/s]
#
#
#
# Inferring tables for page 1-263:   1%|          | 3/262 [00:02<03:11,  1.35it/s]
#
#
#
# Inferring tables for page 1-263:   2%|▏         | 4/262 [00:03<03:20,  1.28it/s]
#
#
#
# Inferring tables for page 1-263:   2%|▏         | 5/262 [00:04<02:55,  1.46it/s]
#
#
#
# Inferring tables for page 1-263:   2%|▏         | 6/262 [00:04<02:16,  1.88it/s]
#
#
#
# Inferring tables for page 1-263:   3%|▎         | 7/262 [00:04<01:48,  2.36it/s]
#
#
#
# Inferring tables for page 1-263:   3%|▎         | 8/262 [00:04<01:35,  2.65it/s]
#
#
#
# Inferring tables for page 1-263:   3%|▎         | 9/262 [00:04<01:25,  2.94it/s]
#
#
#
# Inferring tables for page 1-263:   4%|▍         | 10/262 [00:05<01:13,  3.42it/s]
#
#
#
# Inferring tables for page 1-263:   4%|▍         | 11/262 [00:05<01:04,  3.87it/s]
#
#
#
# Inferring tables for page 1-263:   5%|▍         | 12/262 [00:05<00:59,  4.23it/s]
#
#
#
# Inferring tables for page 1-263:   5%|▍         | 13/262 [00:05<00:56,  4.43it/s]
#
#
#
# Inferring tables for page 1-263:   5%|▌         | 14/262 [00:05<01:01,  4.06it/s]
#
#
#
# Inferring tables for page 1-263:   6%|▌         | 15/262 [00:06<00:57,  4.30it/s]
#
#
#
# Inferring tables for page 1-263:   6%|▌         | 16/262 [00:06<00:52,  4.65it/s]
#
#
#
# Inferring tables for page 1-263:   6%|▋         | 17/262 [00:07<01:24,  2.89it/s]
#
#
#
# Inferring tables for page 1-263:   7%|▋         | 18/262 [00:07<01:23,  2.94it/s]
#
#
#
# Inferring tables for page 1-263:   7%|▋         | 19/262 [00:07<01:38,  2.46it/s]
#
#
#
# Inferring tables for page 1-263:   8%|▊         | 20/262 [00:08<01:21,  2.98it/s]
#
#
#
# Inferring tables for page 1-263:   8%|▊         | 21/262 [00:08<01:11,  3.35it/s]
#
#
#
# Inferring tables for page 1-263:   8%|▊         | 22/262 [00:08<01:04,  3.75it/s]
#
#
#
# Inferring tables for page 1-263:   9%|▉         | 23/262 [00:08<00:59,  4.02it/s]
#
#
#
# Inferring tables for page 1-263:   9%|▉         | 24/262 [00:08<00:52,  4.51it/s]
#
#
#
# Inferring tables for page 1-263:  10%|▉         | 25/262 [00:09<00:54,  4.36it/s]
#
#
#
# Inferring tables for page 1-263:  10%|▉         | 26/262 [00:09<00:49,  4.74it/s]
#
#
#
# Inferring tables for page 1-263:  10%|█         | 27/262 [00:09<00:45,  5.12it/s]
#
#
#
# Inferring tables for page 1-263:  11%|█         | 28/262 [00:09<00:44,  5.30it/s]
#
#
#
# Inferring tables for page 1-263:  11%|█         | 29/262 [00:09<00:44,  5.22it/s]
#
#
#
# Inferring tables for page 1-263:  11%|█▏        | 30/262 [00:10<00:48,  4.79it/s]
#
#
#
# Inferring tables for page 1-263:  12%|█▏        | 31/262 [00:10<01:04,  3.58it/s]
#
#
#
# Inferring tables for page 1-263:  12%|█▏        | 32/262 [00:10<00:55,  4.11it/s]
#
#
#
# Inferring tables for page 1-263:  13%|█▎        | 33/262 [00:10<00:50,  4.58it/s]
#
#
#
# Inferring tables for page 1-263:  13%|█▎        | 34/262 [00:11<01:31,  2.50it/s]
#
#
#
# Inferring tables for page 1-263:  13%|█▎        | 35/262 [00:12<01:44,  2.16it/s]
#
#
#
# Inferring tables for page 1-263:  14%|█▎        | 36/262 [00:12<01:24,  2.66it/s]
#
#
#
# Inferring tables for page 1-263:  14%|█▍        | 37/262 [00:12<01:29,  2.51it/s]
#
#
#
# Inferring tables for page 1-263:  15%|█▍        | 38/262 [00:13<01:23,  2.68it/s]
#
#
#
# Inferring tables for page 1-263:  15%|█▍        | 39/262 [00:13<01:08,  3.24it/s]
#
#
#
# Inferring tables for page 1-263:  15%|█▌        | 40/262 [00:13<01:13,  3.03it/s]
#
#
#
# Inferring tables for page 1-263:  16%|█▌        | 41/262 [00:13<01:05,  3.39it/s]
#
#
#
# Inferring tables for page 1-263:  16%|█▌        | 42/262 [00:14<00:55,  3.94it/s]
#
#
#
# Inferring tables for page 1-263:  16%|█▋        | 43/262 [00:14<00:53,  4.11it/s]
#
#
#
# Inferring tables for page 1-263:  17%|█▋        | 44/262 [00:14<01:10,  3.09it/s]
#
#
#
# Inferring tables for page 1-263:  17%|█▋        | 45/262 [00:15<01:34,  2.29it/s]
#
#
#
# Inferring tables for page 1-263:  18%|█▊        | 46/262 [00:15<01:32,  2.34it/s]
#
#
#
# Inferring tables for page 1-263:  18%|█▊        | 47/262 [00:16<01:14,  2.88it/s]
#
#
#
# Inferring tables for page 1-263:  18%|█▊        | 48/262 [00:16<01:06,  3.23it/s]
#
#
#
# Inferring tables for page 1-263:  19%|█▊        | 49/262 [00:16<01:01,  3.47it/s]
#
#
#
# Inferring tables for page 1-263:  19%|█▉        | 50/262 [00:16<01:01,  3.47it/s]
#
#
#
# Inferring tables for page 1-263:  19%|█▉        | 51/262 [00:17<01:01,  3.44it/s]
#
#
#
# Inferring tables for page 1-263:  20%|█▉        | 52/262 [00:17<00:52,  3.98it/s]
#
#
#
# Inferring tables for page 1-263:  20%|██        | 53/262 [00:17<00:57,  3.65it/s]
#
#
#
# Inferring tables for page 1-263:  21%|██        | 54/262 [00:17<00:50,  4.16it/s]
#
#
#
# Inferring tables for page 1-263:  21%|██        | 55/262 [00:18<01:04,  3.21it/s]
#
#
#
# Inferring tables for page 1-263:  21%|██▏       | 56/262 [00:18<00:54,  3.77it/s]
#
#
#
# Inferring tables for page 1-263:  22%|██▏       | 57/262 [00:18<00:55,  3.72it/s]
#
#
#
# Inferring tables for page 1-263:  22%|██▏       | 58/262 [00:19<01:13,  2.77it/s]
#
#
#
# Inferring tables for page 1-263:  23%|██▎       | 59/262 [00:19<01:09,  2.90it/s]
#
#
#
# Inferring tables for page 1-263:  23%|██▎       | 60/262 [00:19<01:11,  2.83it/s]
#
#
#
# Inferring tables for page 1-263:  23%|██▎       | 61/262 [00:20<01:05,  3.07it/s]
#
#
#
# Inferring tables for page 1-263:  24%|██▎       | 62/262 [00:20<01:12,  2.76it/s]
#
#
#
# Inferring tables for page 1-263:  24%|██▍       | 63/262 [00:20<01:00,  3.32it/s]
#
#
#
# Inferring tables for page 1-263:  24%|██▍       | 64/262 [00:21<01:09,  2.86it/s]
#
#
#
# Inferring tables for page 1-263:  25%|██▍       | 65/262 [00:21<01:19,  2.47it/s]
#
#
#
# Inferring tables for page 1-263:  25%|██▌       | 66/262 [00:22<01:29,  2.18it/s]
#
#
#
# Inferring tables for page 1-263:  26%|██▌       | 67/262 [00:22<01:33,  2.08it/s]
#
#
#
# Inferring tables for page 1-263:  26%|██▌       | 68/262 [00:23<01:36,  2.01it/s]
#
#
#
# Inferring tables for page 1-263:  26%|██▋       | 69/262 [00:24<02:11,  1.47it/s]
#
#
#
# Inferring tables for page 1-263:  27%|██▋       | 70/262 [00:24<01:57,  1.64it/s]
#
#
#
# Inferring tables for page 1-263:  27%|██▋       | 71/262 [00:25<01:48,  1.76it/s]
#
#
#
# Inferring tables for page 1-263:  27%|██▋       | 72/262 [00:26<01:46,  1.79it/s]
#
#
#
# Inferring tables for page 1-263:  28%|██▊       | 73/262 [00:26<01:48,  1.75it/s]
#
#
#
# Inferring tables for page 1-263:  28%|██▊       | 74/262 [00:27<02:00,  1.55it/s]
#
#
#
# Inferring tables for page 1-263:  29%|██▊       | 75/262 [00:27<01:47,  1.73it/s]
#
#
#
# Inferring tables for page 1-263:  29%|██▉       | 76/262 [00:28<01:48,  1.71it/s]
#
#
#
# Inferring tables for page 1-263:  29%|██▉       | 77/262 [00:29<02:19,  1.33it/s]
#
#
#
# Inferring tables for page 1-263:  30%|██▉       | 78/262 [00:30<02:26,  1.26it/s]
#
#
#
# Inferring tables for page 1-263:  30%|███       | 79/262 [00:30<02:03,  1.48it/s]
#
#
#
# Inferring tables for page 1-263:  31%|███       | 80/262 [00:31<01:40,  1.82it/s]
#
#
#
# Inferring tables for page 1-263:  31%|███       | 81/262 [00:32<01:58,  1.53it/s]
#
#
#
# Inferring tables for page 1-263:  31%|███▏      | 82/262 [00:32<01:58,  1.52it/s]
#
#
#
# Inferring tables for page 1-263:  32%|███▏      | 83/262 [00:33<01:55,  1.55it/s]
#
#
#
# Inferring tables for page 1-263:  32%|███▏      | 84/262 [00:33<01:42,  1.73it/s]
#
#
#
# Inferring tables for page 1-263:  32%|███▏      | 85/262 [00:34<01:43,  1.71it/s]
#
#
#
# Inferring tables for page 1-263:  33%|███▎      | 86/262 [00:34<01:26,  2.03it/s]
#
#
#
# Inferring tables for page 1-263:  33%|███▎      | 87/262 [00:35<01:33,  1.87it/s]
#
#
#
# Inferring tables for page 1-263:  34%|███▎      | 88/262 [00:35<01:34,  1.85it/s]
#
#
#
# Inferring tables for page 1-263:  34%|███▍      | 89/262 [00:36<01:35,  1.82it/s]
#
#
#
# Inferring tables for page 1-263:  34%|███▍      | 90/262 [00:36<01:25,  2.01it/s]
#
#
#
# Inferring tables for page 1-263:  35%|███▍      | 91/262 [00:37<01:19,  2.15it/s]
#
#
#
# Inferring tables for page 1-263:  35%|███▌      | 92/262 [00:37<01:20,  2.11it/s]
#
#
#
# Inferring tables for page 1-263:  35%|███▌      | 93/262 [00:37<01:11,  2.38it/s]
#
#
#
# Inferring tables for page 1-263:  36%|███▌      | 94/262 [00:38<01:28,  1.91it/s]
#
#
#
# Inferring tables for page 1-263:  36%|███▋      | 95/262 [00:39<01:32,  1.80it/s]
#
#
#
# Inferring tables for page 1-263:  37%|███▋      | 96/262 [00:39<01:25,  1.93it/s]
#
#
#
# Inferring tables for page 1-263:  37%|███▋      | 97/262 [00:39<01:11,  2.30it/s]
#
#
#
# Inferring tables for page 1-263:  37%|███▋      | 98/262 [00:40<01:10,  2.32it/s]
#
#
#
# Inferring tables for page 1-263:  38%|███▊      | 99/262 [00:40<01:02,  2.61it/s]
#
#
#
# Inferring tables for page 1-263:  38%|███▊      | 100/262 [00:41<01:03,  2.57it/s]
#
#
#
# Inferring tables for page 1-263:  39%|███▊      | 101/262 [00:41<01:09,  2.32it/s]
#
#
#
# Inferring tables for page 1-263:  39%|███▉      | 102/262 [00:41<01:02,  2.55it/s]
#
#
#
# Inferring tables for page 1-263:  39%|███▉      | 103/262 [00:42<00:54,  2.90it/s]
#
#
#
# Inferring tables for page 1-263:  40%|███▉      | 104/262 [00:42<00:45,  3.46it/s]
#
#
#
# Inferring tables for page 1-263:  40%|████      | 105/262 [00:42<00:51,  3.04it/s]
#
#
#
# Inferring tables for page 1-263:  40%|████      | 106/262 [00:43<01:03,  2.44it/s]
#
#
#
# Inferring tables for page 1-263:  41%|████      | 107/262 [00:43<00:53,  2.91it/s]
#
#
#
# Inferring tables for page 1-263:  41%|████      | 108/262 [00:44<01:07,  2.27it/s]
#
#
#
# Inferring tables for page 1-263:  42%|████▏     | 109/262 [00:44<01:00,  2.51it/s]
#
#
#
# Inferring tables for page 1-263:  42%|████▏     | 110/262 [00:44<00:52,  2.88it/s]
#
#
#
# Inferring tables for page 1-263:  42%|████▏     | 111/262 [00:44<00:44,  3.37it/s]
#
#
#
# Inferring tables for page 1-263:  43%|████▎     | 112/262 [00:45<00:39,  3.82it/s]
#
#
#
# Inferring tables for page 1-263:  43%|████▎     | 113/262 [00:45<00:35,  4.24it/s]
#
#
#
# Inferring tables for page 1-263:  44%|████▎     | 114/262 [00:45<00:37,  3.92it/s]
#
#
#
# Inferring tables for page 1-263:  44%|████▍     | 115/262 [00:45<00:34,  4.32it/s]
#
#
#
# Inferring tables for page 1-263:  44%|████▍     | 116/262 [00:46<00:39,  3.69it/s]
#
#
#
# Inferring tables for page 1-263:  45%|████▍     | 117/262 [00:46<00:39,  3.67it/s]
#
#
#
# Inferring tables for page 1-263:  45%|████▌     | 118/262 [00:46<00:34,  4.18it/s]
#
#
#
# Inferring tables for page 1-263:  45%|████▌     | 119/262 [00:46<00:33,  4.26it/s]
#
#
#
# Inferring tables for page 1-263:  46%|████▌     | 120/262 [00:46<00:30,  4.63it/s]
#
#
#
# Inferring tables for page 1-263:  46%|████▌     | 121/262 [00:47<00:29,  4.71it/s]
#
#
#
# Inferring tables for page 1-263:  47%|████▋     | 122/262 [00:47<00:43,  3.25it/s]
#
#
#
# Inferring tables for page 1-263:  47%|████▋     | 123/262 [00:48<00:46,  2.98it/s]
#
#
#
# Inferring tables for page 1-263:  47%|████▋     | 124/262 [00:48<00:53,  2.58it/s]
#
#
#
# Inferring tables for page 1-263:  48%|████▊     | 125/262 [00:48<00:43,  3.14it/s]
#
#
#
# Inferring tables for page 1-263:  48%|████▊     | 126/262 [00:49<00:47,  2.84it/s]
#
#
#
# Inferring tables for page 1-263:  48%|████▊     | 127/262 [00:49<00:50,  2.67it/s]
#
#
#
# Inferring tables for page 1-263:  49%|████▉     | 128/262 [00:50<00:56,  2.38it/s]
#
#
#
# Inferring tables for page 1-263:  49%|████▉     | 129/262 [00:50<01:04,  2.07it/s]
#
#
#
# Inferring tables for page 1-263:  50%|████▉     | 130/262 [00:51<00:55,  2.37it/s]
#
#
#
# Inferring tables for page 1-263:  50%|█████     | 131/262 [00:51<00:47,  2.74it/s]
#
#
#
# Inferring tables for page 1-263:  50%|█████     | 132/262 [00:51<00:41,  3.11it/s]
#
#
#
# Inferring tables for page 1-263:  51%|█████     | 133/262 [00:51<00:35,  3.64it/s]
#
#
#
# Inferring tables for page 1-263:  51%|█████     | 134/262 [00:51<00:30,  4.15it/s]
#
#
#
# Inferring tables for page 1-263:  52%|█████▏    | 135/262 [00:51<00:27,  4.55it/s]
#
#
#
# Inferring tables for page 1-263:  52%|█████▏    | 136/262 [00:52<00:25,  4.94it/s]
#
#
#
# Inferring tables for page 1-263:  52%|█████▏    | 137/262 [00:52<00:34,  3.67it/s]
#
#
#
# Inferring tables for page 1-263:  53%|█████▎    | 138/262 [00:52<00:29,  4.18it/s]
#
#
#
# Inferring tables for page 1-263:  53%|█████▎    | 139/262 [00:53<00:36,  3.33it/s]
#
#
#
# Inferring tables for page 1-263:  53%|█████▎    | 140/262 [00:53<00:31,  3.84it/s]
#
#
#
# Inferring tables for page 1-263:  54%|█████▍    | 141/262 [00:54<00:50,  2.41it/s]
#
#
#
# Inferring tables for page 1-263:  54%|█████▍    | 142/262 [00:54<00:47,  2.54it/s]
#
#
#
# Inferring tables for page 1-263:  55%|█████▍    | 143/262 [00:54<00:47,  2.53it/s]
#
#
#
# Inferring tables for page 1-263:  55%|█████▍    | 144/262 [00:55<00:38,  3.08it/s]
#
#
#
# Inferring tables for page 1-263:  55%|█████▌    | 145/262 [00:55<00:38,  3.02it/s]
#
#
#
# Inferring tables for page 1-263:  56%|█████▌    | 146/262 [00:55<00:36,  3.19it/s]
#
#
#
# Inferring tables for page 1-263:  56%|█████▌    | 147/262 [00:55<00:31,  3.66it/s]
#
#
#
# Inferring tables for page 1-263:  56%|█████▋    | 148/262 [00:55<00:27,  4.19it/s]
#
#
#
# Inferring tables for page 1-263:  57%|█████▋    | 149/262 [00:56<00:24,  4.66it/s]
#
#
#
# Inferring tables for page 1-263:  57%|█████▋    | 150/262 [00:56<00:22,  5.05it/s]
#
#
#
# Inferring tables for page 1-263:  58%|█████▊    | 151/262 [00:56<00:20,  5.35it/s]
#
#
#
# Inferring tables for page 1-263:  58%|█████▊    | 152/262 [00:56<00:25,  4.25it/s]
#
#
#
# Inferring tables for page 1-263:  58%|█████▊    | 153/262 [00:57<00:24,  4.47it/s]
#
#
#
# Inferring tables for page 1-263:  59%|█████▉    | 154/262 [00:57<00:27,  3.89it/s]
#
#
#
# Inferring tables for page 1-263:  59%|█████▉    | 155/262 [00:57<00:24,  4.29it/s]
#
#
#
# Inferring tables for page 1-263:  60%|█████▉    | 156/262 [00:57<00:22,  4.76it/s]
#
#
#
# Inferring tables for page 1-263:  60%|█████▉    | 157/262 [00:57<00:20,  5.15it/s]
#
#
#
# Inferring tables for page 1-263:  60%|██████    | 158/262 [00:58<00:49,  2.12it/s]
#
#
#
# Inferring tables for page 1-263:  61%|██████    | 159/262 [01:00<01:08,  1.50it/s]
#
#
#
# Inferring tables for page 1-263:  61%|██████    | 160/262 [01:01<01:17,  1.32it/s]
#
#
#
# Inferring tables for page 1-263:  61%|██████▏   | 161/262 [01:01<01:20,  1.25it/s]
#
#
#
# Inferring tables for page 1-263:  62%|██████▏   | 162/262 [01:02<01:01,  1.62it/s]
#
#
#
# Inferring tables for page 1-263:  62%|██████▏   | 163/262 [01:03<01:13,  1.34it/s]
#
#
#
# Inferring tables for page 1-263:  63%|██████▎   | 164/262 [01:03<00:55,  1.75it/s]
#
#
#
# Inferring tables for page 1-263:  63%|██████▎   | 165/262 [01:03<00:43,  2.23it/s]
#
#
#
# Inferring tables for page 1-263:  63%|██████▎   | 166/262 [01:03<00:35,  2.72it/s]
#
#
#
# Inferring tables for page 1-263:  64%|██████▎   | 167/262 [01:03<00:29,  3.26it/s]
#
#
#
# Inferring tables for page 1-263:  64%|██████▍   | 168/262 [01:04<00:25,  3.72it/s]
#
#
#
# Inferring tables for page 1-263:  65%|██████▍   | 169/262 [01:04<00:42,  2.18it/s]
#
#
#
# Inferring tables for page 1-263:  65%|██████▍   | 170/262 [01:05<00:33,  2.71it/s]
#
#
#
# Inferring tables for page 1-263:  65%|██████▌   | 171/262 [01:05<00:31,  2.85it/s]
#
#
#
# Inferring tables for page 1-263:  66%|██████▌   | 172/262 [01:05<00:26,  3.41it/s]
#
#
#
# Inferring tables for page 1-263:  66%|██████▌   | 173/262 [01:06<00:38,  2.33it/s]
#
#
#
# Inferring tables for page 1-263:  66%|██████▋   | 174/262 [01:07<00:50,  1.75it/s]
#
#
#
# Inferring tables for page 1-263:  67%|██████▋   | 175/262 [01:08<01:02,  1.39it/s]
#
#
#
# Inferring tables for page 1-263:  67%|██████▋   | 176/262 [01:09<01:05,  1.32it/s]
#
#
#
# Inferring tables for page 1-263:  68%|██████▊   | 177/262 [01:10<01:08,  1.25it/s]
#
#
#
# Inferring tables for page 1-263:  68%|██████▊   | 178/262 [01:10<00:51,  1.64it/s]
#
#
#
# Inferring tables for page 1-263:  68%|██████▊   | 179/262 [01:10<00:39,  2.10it/s]
#
#
#
# Inferring tables for page 1-263:  69%|██████▊   | 180/262 [01:10<00:31,  2.62it/s]
#
#
#
# Inferring tables for page 1-263:  69%|██████▉   | 181/262 [01:10<00:25,  3.16it/s]
#
#
#
# Inferring tables for page 1-263:  69%|██████▉   | 182/262 [01:11<00:33,  2.41it/s]
#
#
#
# Inferring tables for page 1-263:  70%|██████▉   | 183/262 [01:11<00:29,  2.64it/s]
#
#
#
# Inferring tables for page 1-263:  70%|███████   | 184/262 [01:11<00:24,  3.21it/s]
#
#
#
# Inferring tables for page 1-263:  71%|███████   | 185/262 [01:11<00:20,  3.68it/s]
#
#
#
# Inferring tables for page 1-263:  71%|███████   | 186/262 [01:12<00:18,  4.19it/s]
#
#
#
# Inferring tables for page 1-263:  71%|███████▏  | 187/262 [01:12<00:16,  4.64it/s]
#
#
#
# Inferring tables for page 1-263:  72%|███████▏  | 188/262 [01:12<00:14,  5.02it/s]
#
#
#
# Inferring tables for page 1-263:  72%|███████▏  | 189/262 [01:12<00:21,  3.45it/s]
#
#
#
# Inferring tables for page 1-263:  73%|███████▎  | 190/262 [01:13<00:27,  2.63it/s]
#
#
#
# Inferring tables for page 1-263:  73%|███████▎  | 191/262 [01:14<00:35,  2.02it/s]
#
#
#
# Inferring tables for page 1-263:  73%|███████▎  | 192/262 [01:14<00:27,  2.52it/s]
#
#
#
# Inferring tables for page 1-263:  74%|███████▎  | 193/262 [01:14<00:28,  2.42it/s]
#
#
#
# Inferring tables for page 1-263:  74%|███████▍  | 194/262 [01:15<00:29,  2.29it/s]
#
#
#
# Inferring tables for page 1-263:  74%|███████▍  | 195/262 [01:16<00:33,  1.99it/s]
#
#
#
# Inferring tables for page 1-263:  75%|███████▍  | 196/262 [01:16<00:37,  1.74it/s]
#
#
#
# Inferring tables for page 1-263:  75%|███████▌  | 197/262 [01:17<00:48,  1.35it/s]
#
#
#
# Inferring tables for page 1-263:  76%|███████▌  | 198/262 [01:19<00:55,  1.16it/s]
#
#
#
# Inferring tables for page 1-263:  76%|███████▌  | 199/262 [01:19<00:45,  1.38it/s]
#
#
#
# Inferring tables for page 1-263:  76%|███████▋  | 200/262 [01:19<00:40,  1.52it/s]
#
#
#
# Inferring tables for page 1-263:  77%|███████▋  | 201/262 [01:20<00:35,  1.74it/s]
#
#
#
# Inferring tables for page 1-263:  77%|███████▋  | 202/262 [01:20<00:34,  1.73it/s]
#
#
#
# Inferring tables for page 1-263:  77%|███████▋  | 203/262 [01:21<00:37,  1.58it/s]
#
#
#
# Inferring tables for page 1-263:  78%|███████▊  | 204/262 [01:22<00:36,  1.57it/s]
#
#
#
# Inferring tables for page 1-263:  78%|███████▊  | 205/262 [01:22<00:35,  1.59it/s]
#
#
#
# Inferring tables for page 1-263:  79%|███████▊  | 206/262 [01:23<00:33,  1.65it/s]
#
#
#
# Inferring tables for page 1-263:  79%|███████▉  | 207/262 [01:24<00:34,  1.57it/s]
#
#
#
# Inferring tables for page 1-263:  79%|███████▉  | 208/262 [01:24<00:35,  1.52it/s]
#
#
#
# Inferring tables for page 1-263:  80%|███████▉  | 209/262 [01:25<00:37,  1.41it/s]
#
#
#
# Inferring tables for page 1-263:  80%|████████  | 210/262 [01:26<00:38,  1.36it/s]
#
#
#
# Inferring tables for page 1-263:  81%|████████  | 211/262 [01:27<00:34,  1.48it/s]
#
#
#
# Inferring tables for page 1-263:  81%|████████  | 212/262 [01:27<00:30,  1.64it/s]
#
#
#
# Inferring tables for page 1-263:  81%|████████▏ | 213/262 [01:28<00:28,  1.72it/s]
#
#
#
# Inferring tables for page 1-263:  82%|████████▏ | 214/262 [01:28<00:23,  2.03it/s]
#
#
#
# Inferring tables for page 1-263:  82%|████████▏ | 215/262 [01:28<00:24,  1.90it/s]
#
#
#
# Inferring tables for page 1-263:  82%|████████▏ | 216/262 [01:29<00:19,  2.40it/s]
#
#
#
# Inferring tables for page 1-263:  83%|████████▎ | 217/262 [01:29<00:23,  1.94it/s]
#
#
#
# Inferring tables for page 1-263:  83%|████████▎ | 218/262 [01:30<00:23,  1.83it/s]
#
#
#
# Inferring tables for page 1-263:  84%|████████▎ | 219/262 [01:31<00:27,  1.58it/s]
#
#
#
# Inferring tables for page 1-263:  84%|████████▍ | 220/262 [01:32<00:29,  1.44it/s]
#
#
#
# Inferring tables for page 1-263:  84%|████████▍ | 221/262 [01:32<00:26,  1.53it/s]
#
#
#
# Inferring tables for page 1-263:  85%|████████▍ | 222/262 [01:33<00:30,  1.30it/s]
#
#
#
# Inferring tables for page 1-263:  85%|████████▌ | 223/262 [01:34<00:27,  1.41it/s]
#
#
#
# Inferring tables for page 1-263:  85%|████████▌ | 224/262 [01:34<00:26,  1.44it/s]
#
#
#
# Inferring tables for page 1-263:  86%|████████▌ | 225/262 [01:35<00:23,  1.60it/s]
#
#
#
# Inferring tables for page 1-263:  86%|████████▋ | 226/262 [01:36<00:22,  1.58it/s]
#
#
#
# Inferring tables for page 1-263:  87%|████████▋ | 227/262 [01:36<00:19,  1.78it/s]
#
#
#
# Inferring tables for page 1-263:  87%|████████▋ | 228/262 [01:37<00:21,  1.61it/s]
#
#
#
# Inferring tables for page 1-263:  87%|████████▋ | 229/262 [01:38<00:23,  1.43it/s]
#
#
#
# Inferring tables for page 1-263:  88%|████████▊ | 230/262 [01:38<00:21,  1.52it/s]
#
#
#
# Inferring tables for page 1-263:  88%|████████▊ | 231/262 [01:39<00:19,  1.63it/s]
#
#
#
# Inferring tables for page 1-263:  89%|████████▊ | 232/262 [01:39<00:16,  1.82it/s]
#
#
#
# Inferring tables for page 1-263:  89%|████████▉ | 233/262 [01:40<00:15,  1.86it/s]
#
#
#
# Inferring tables for page 1-263:  89%|████████▉ | 234/262 [01:40<00:13,  2.04it/s]
#
#
#
# Inferring tables for page 1-263:  90%|████████▉ | 235/262 [01:41<00:13,  1.96it/s]
#
#
#
# Inferring tables for page 1-263:  90%|█████████ | 236/262 [01:41<00:14,  1.84it/s]
#
#
#
# Inferring tables for page 1-263:  90%|█████████ | 237/262 [01:42<00:13,  1.90it/s]
#
#
#
# Inferring tables for page 1-263:  91%|█████████ | 238/262 [01:42<00:09,  2.40it/s]
#
#
#
# Inferring tables for page 1-263:  91%|█████████ | 239/262 [01:42<00:07,  2.89it/s]
#
#
#
# Inferring tables for page 1-263:  92%|█████████▏| 240/262 [01:42<00:06,  3.42it/s]
#
#
#
# Inferring tables for page 1-263:  92%|█████████▏| 241/262 [01:43<00:07,  2.70it/s]
#
#
#
# Inferring tables for page 1-263:  92%|█████████▏| 242/262 [01:43<00:08,  2.33it/s]
#
#
#
# Inferring tables for page 1-263:  93%|█████████▎| 243/262 [01:44<00:09,  2.09it/s]
#
#
#
# Inferring tables for page 1-263:  93%|█████████▎| 244/262 [01:45<00:09,  1.86it/s]
#
#
#
# Inferring tables for page 1-263:  94%|█████████▎| 245/262 [01:45<00:10,  1.55it/s]
#
#
#
# Inferring tables for page 1-263:  94%|█████████▍| 246/262 [01:46<00:09,  1.66it/s]
#
#
#
# Inferring tables for page 1-263:  94%|█████████▍| 247/262 [01:47<00:10,  1.38it/s]
#
#
#
# Inferring tables for page 1-263:  95%|█████████▍| 248/262 [01:48<00:11,  1.25it/s]
#
#
#
# Inferring tables for page 1-263:  95%|█████████▌| 249/262 [01:48<00:08,  1.57it/s]
#
#
#
# Inferring tables for page 1-263:  95%|█████████▌| 250/262 [01:48<00:05,  2.01it/s]
#
#
#
# Inferring tables for page 1-263:  96%|█████████▌| 251/262 [01:50<00:07,  1.45it/s]
#
#
#
# Inferring tables for page 1-263:  96%|█████████▌| 252/262 [01:51<00:08,  1.20it/s]
#
#
#
# Inferring tables for page 1-263:  97%|█████████▋| 253/262 [01:51<00:07,  1.22it/s]
#
#
#
# Inferring tables for page 1-263:  97%|█████████▋| 254/262 [01:52<00:04,  1.60it/s]
#
#
#
# Inferring tables for page 1-263:  97%|█████████▋| 255/262 [01:52<00:03,  2.02it/s]
#
#
#
# Inferring tables for page 1-263:  98%|█████████▊| 256/262 [01:52<00:02,  2.47it/s]
#
#
#
# Inferring tables for page 1-263:  98%|█████████▊| 257/262 [01:52<00:01,  3.02it/s]
#
#
#
# Inferring tables for page 1-263:  98%|█████████▊| 258/262 [01:52<00:01,  3.52it/s]
#
#
#
# Inferring tables for page 1-263:  99%|█████████▉| 259/262 [01:53<00:01,  1.94it/s]
#
#
#
# Inferring tables for page 1-263:  99%|█████████▉| 260/262 [01:54<00:01,  1.76it/s]
#
#
#
# Inferring tables for page 1-263: 100%|█████████▉| 261/262 [01:54<00:00,  2.00it/s]
#
#
#
# Inferring tables for page 1-263: 100%|██████████| 262/262 [01:55<00:00,  2.27it/s]
#
#
#
# Page: 100%|█████████▉| 262/263 [05:20<00:01,  1.23s/it]
#
#
#
# Inferring tables for page 263-525: 0it [00:00, ?it/s]
#
#
#
# Page: 524it [05:21,  1.17it/s]
#
#
#
# Extracting and saving tables:   0%|          | 0/154 [00:00<?, ?it/s]
#
#
# Page: 524it [05:33,  1.17it/s]
#
#
#
# Extracting and saving tables:   1%|          | 1/154 [00:15<40:33, 15.90s/it]
#
#
#
# Extracting and saving tables:   1%|▏         | 2/154 [00:25<35:15, 13.92s/it]
#
#
#
# Extracting and saving tables:   2%|▏         | 3/154 [00:34<31:37, 12.56s/it]
#
#
#
# Extracting and saving tables:   3%|▎         | 4/154 [00:37<24:13,  9.69s/it]
#
#
#
# Extracting and saving tables:   3%|▎         | 5/154 [00:40<19:02,  7.67s/it]
#
#
#
# Extracting and saving tables:   4%|▍         | 6/154 [00:43<15:32,  6.30s/it]
#
#
#
# Extracting and saving tables:   5%|▍         | 7/154 [00:46<13:06,  5.35s/it]
#
#
#
# Extracting and saving tables:   5%|▌         | 8/154 [00:52<13:34,  5.58s/it]
#
#
#
# Extracting and saving tables:   6%|▌         | 9/154 [00:59<13:53,  5.75s/it]
#
#
#
# Extracting and saving tables:   6%|▋         | 10/154 [01:02<11:52,  4.95s/it]
#
#
#
# Extracting and saving tables:   7%|▋         | 11/154 [01:08<12:37,  5.30s/it]
#
#
#
# Extracting and saving tables:   8%|▊         | 12/154 [01:17<15:09,  6.40s/it]
#
#
#
# Extracting and saving tables:   8%|▊         | 13/154 [01:20<12:43,  5.42s/it]
#
#
#
# Extracting and saving tables:   9%|▉         | 14/154 [01:23<11:00,  4.72s/it]
#
#
#
# Extracting and saving tables:  10%|▉         | 15/154 [01:26<09:44,  4.21s/it]
#
#
#
# Extracting and saving tables:  10%|█         | 16/154 [01:29<08:55,  3.88s/it]
#
#
#
# Extracting and saving tables:  11%|█         | 17/154 [01:35<10:33,  4.62s/it]
#
#
#
# Extracting and saving tables:  12%|█▏        | 18/154 [01:38<09:26,  4.16s/it]
#
#
#
# Extracting and saving tables:  12%|█▏        | 19/154 [01:48<13:02,  5.80s/it]
#
#
#
# Extracting and saving tables:  13%|█▎        | 20/154 [01:51<11:06,  4.97s/it]
#
#
#
# Extracting and saving tables:  14%|█▎        | 21/154 [01:54<09:44,  4.40s/it]
#
#
#
# Extracting and saving tables:  14%|█▍        | 22/154 [02:00<10:52,  4.95s/it]
#
#
#
# Extracting and saving tables:  15%|█▍        | 23/154 [02:07<11:35,  5.31s/it]
#
#
#
# Extracting and saving tables:  16%|█▌        | 24/154 [02:13<12:06,  5.59s/it]
#
#
#
# Extracting and saving tables:  16%|█▌        | 25/154 [02:16<10:34,  4.92s/it]
#
#
#
# Extracting and saving tables:  17%|█▋        | 26/154 [02:19<09:21,  4.39s/it]
#
#
#
# Extracting and saving tables:  18%|█▊        | 27/154 [02:29<12:29,  5.90s/it]
#
#
#
# Extracting and saving tables:  18%|█▊        | 28/154 [02:38<14:23,  6.85s/it]
#
#
#
# Extracting and saving tables:  19%|█▉        | 29/154 [02:41<12:02,  5.78s/it]
#
#
#
# Extracting and saving tables:  19%|█▉        | 30/154 [02:44<10:23,  5.03s/it]
#
#
#
# Extracting and saving tables:  20%|██        | 31/154 [02:48<09:11,  4.49s/it]
#
#
#
# Extracting and saving tables:  21%|██        | 32/154 [02:51<08:19,  4.10s/it]
#
#
#
# Extracting and saving tables:  21%|██▏       | 33/154 [02:57<09:36,  4.77s/it]
#
#
#
# Extracting and saving tables:  22%|██▏       | 34/154 [03:03<10:21,  5.18s/it]
#
#
#
# Extracting and saving tables:  23%|██▎       | 35/154 [03:06<09:06,  4.59s/it]
#
#
#
# Extracting and saving tables:  23%|██▎       | 36/154 [03:16<11:50,  6.02s/it]
#
#
#
# Extracting and saving tables:  24%|██▍       | 37/154 [03:28<15:32,  7.97s/it]
#
#
#
# Extracting and saving tables:  25%|██▍       | 38/154 [03:31<12:32,  6.49s/it]
#
#
#
# Extracting and saving tables:  25%|██▌       | 39/154 [03:38<12:13,  6.38s/it]
#
#
#
# Extracting and saving tables:  26%|██▌       | 40/154 [03:41<10:17,  5.41s/it]
#
#
#
# Extracting and saving tables:  27%|██▋       | 41/154 [03:44<08:53,  4.72s/it]
#
#
#
# Extracting and saving tables:  27%|██▋       | 42/154 [03:47<07:54,  4.24s/it]
#
#
#
# Extracting and saving tables:  28%|██▊       | 43/154 [03:50<07:12,  3.90s/it]
#
#
#
# Extracting and saving tables:  29%|██▊       | 44/154 [03:56<08:18,  4.53s/it]
#
#
#
# Extracting and saving tables:  29%|██▉       | 45/154 [04:02<09:05,  5.00s/it]
#
#
#
# Extracting and saving tables:  30%|██▉       | 46/154 [04:08<09:40,  5.37s/it]
#
#
#
# Extracting and saving tables:  31%|███       | 47/154 [04:11<08:17,  4.65s/it]
#
#
#
# Extracting and saving tables:  31%|███       | 48/154 [04:14<07:23,  4.18s/it]
#
#
#
# Extracting and saving tables:  32%|███▏      | 49/154 [04:18<06:44,  3.86s/it]
#
#
#
# Extracting and saving tables:  32%|███▏      | 50/154 [04:24<07:57,  4.60s/it]
#
#
#
# Extracting and saving tables:  33%|███▎      | 51/154 [04:27<07:05,  4.13s/it]
#
#
#
# Extracting and saving tables:  34%|███▍      | 52/154 [04:33<07:57,  4.68s/it]
#
#
#
# Extracting and saving tables:  34%|███▍      | 53/154 [04:39<08:43,  5.19s/it]
#
#
#
# Extracting and saving tables:  35%|███▌      | 54/154 [04:42<07:34,  4.54s/it]
#
#
#
# Extracting and saving tables:  36%|███▌      | 55/154 [04:45<06:47,  4.11s/it]
#
#
#
# Extracting and saving tables:  36%|███▋      | 56/154 [04:48<06:10,  3.78s/it]
#
#
#
# Extracting and saving tables:  37%|███▋      | 57/154 [04:55<07:17,  4.51s/it]
#
#
#
# Extracting and saving tables:  38%|███▊      | 58/154 [04:58<06:31,  4.08s/it]
#
#
#
# Extracting and saving tables:  38%|███▊      | 59/154 [05:01<06:01,  3.80s/it]
#
#
#
# Extracting and saving tables:  39%|███▉      | 60/154 [05:04<05:34,  3.56s/it]
#
#
#
# Extracting and saving tables:  40%|███▉      | 61/154 [05:10<06:45,  4.36s/it]
#
#
#
# Extracting and saving tables:  40%|████      | 62/154 [05:13<06:05,  3.97s/it]
#
#
#
# Extracting and saving tables:  41%|████      | 63/154 [05:16<05:39,  3.73s/it]
#
#
#
# Extracting and saving tables:  42%|████▏     | 64/154 [05:19<05:20,  3.56s/it]
#
#
#
# Extracting and saving tables:  42%|████▏     | 65/154 [05:23<05:04,  3.42s/it]
#
#
#
# Extracting and saving tables:  43%|████▎     | 66/154 [05:26<04:53,  3.33s/it]
#
#
#
# Extracting and saving tables:  44%|████▎     | 67/154 [05:29<04:43,  3.26s/it]
#
#
#
# Extracting and saving tables:  44%|████▍     | 68/154 [05:35<05:55,  4.13s/it]
#
#
#
# Extracting and saving tables:  45%|████▍     | 69/154 [05:38<05:24,  3.82s/it]
#
#
#
# Extracting and saving tables:  45%|████▌     | 70/154 [05:41<05:01,  3.59s/it]
#
#
#
# Extracting and saving tables:  46%|████▌     | 71/154 [05:50<07:21,  5.32s/it]
#
#
#
# Extracting and saving tables:  47%|████▋     | 72/154 [05:53<06:20,  4.65s/it]
#
#
#
# Extracting and saving tables:  47%|████▋     | 73/154 [05:56<05:36,  4.16s/it]
#
#
#
# Extracting and saving tables:  48%|████▊     | 74/154 [05:59<05:04,  3.81s/it]
#
#
#
# Extracting and saving tables:  49%|████▊     | 75/154 [06:03<04:44,  3.61s/it]
#
#
#
# Extracting and saving tables:  49%|████▉     | 76/154 [06:09<05:42,  4.39s/it]
#
#
#
# Extracting and saving tables:  50%|█████     | 77/154 [06:15<06:16,  4.89s/it]
#
#
#
# Extracting and saving tables:  51%|█████     | 78/154 [06:21<06:43,  5.31s/it]
#
#
#
# Extracting and saving tables:  51%|█████▏    | 79/154 [06:24<05:49,  4.67s/it]
#
#
#
# Extracting and saving tables:  52%|█████▏    | 80/154 [06:27<05:07,  4.15s/it]
#
#
#
# Extracting and saving tables:  53%|█████▎    | 81/154 [06:30<04:41,  3.86s/it]
#
#
#
# Extracting and saving tables:  53%|█████▎    | 82/154 [06:34<04:23,  3.65s/it]
#
#
#
# Extracting and saving tables:  54%|█████▍    | 83/154 [06:40<05:14,  4.43s/it]
#
#
#
# Extracting and saving tables:  55%|█████▍    | 84/154 [06:46<05:50,  5.00s/it]
#
#
#
# Extracting and saving tables:  55%|█████▌    | 85/154 [06:49<05:07,  4.46s/it]
#
#
#
# Extracting and saving tables:  56%|█████▌    | 86/154 [06:53<04:42,  4.16s/it]
#
#
#
# Extracting and saving tables:  56%|█████▋    | 87/154 [06:56<04:19,  3.87s/it]
#
#
#
# Extracting and saving tables:  57%|█████▋    | 88/154 [06:59<04:01,  3.66s/it]
#
#
#
# Extracting and saving tables:  58%|█████▊    | 89/154 [07:06<04:50,  4.47s/it]
#
#
#
# Extracting and saving tables:  58%|█████▊    | 90/154 [07:12<05:15,  4.93s/it]
#
#
#
# Extracting and saving tables:  59%|█████▉    | 91/154 [07:15<04:33,  4.35s/it]
#
#
#
# Extracting and saving tables:  60%|█████▉    | 92/154 [07:18<04:09,  4.02s/it]
#
#
#
# Extracting and saving tables:  60%|██████    | 93/154 [07:24<04:50,  4.77s/it]
#
#
#
# Extracting and saving tables:  61%|██████    | 94/154 [07:27<04:15,  4.27s/it]
#
#
#
# Extracting and saving tables:  62%|██████▏   | 95/154 [07:34<04:49,  4.90s/it]
#
#
#
# Extracting and saving tables:  62%|██████▏   | 96/154 [07:40<05:10,  5.35s/it]
#
#
#
# Extracting and saving tables:  63%|██████▎   | 97/154 [07:47<05:22,  5.66s/it]
#
#
#
# Extracting and saving tables:  64%|██████▎   | 98/154 [07:50<04:33,  4.89s/it]
#
#
#
# Extracting and saving tables:  64%|██████▍   | 99/154 [07:56<04:51,  5.30s/it]
#
#
#
# Extracting and saving tables:  65%|██████▍   | 100/154 [07:59<04:10,  4.64s/it]
#
#
#
# Extracting and saving tables:  66%|██████▌   | 101/154 [08:08<05:18,  6.01s/it]
#
#
#
# Extracting and saving tables:  66%|██████▌   | 102/154 [08:15<05:17,  6.11s/it]
#
#
#
# Extracting and saving tables:  67%|██████▋   | 103/154 [08:21<05:15,  6.18s/it]
#
#
#
# Extracting and saving tables:  68%|██████▊   | 104/154 [08:24<04:24,  5.29s/it]
#
#
#
# Extracting and saving tables:  68%|██████▊   | 105/154 [08:27<03:48,  4.65s/it]
#
#
#
# Extracting and saving tables:  69%|██████▉   | 106/154 [08:30<03:20,  4.19s/it]
#
#
#
# Extracting and saving tables:  69%|██████▉   | 107/154 [08:34<03:01,  3.86s/it]
#
#
#
# Extracting and saving tables:  70%|███████   | 108/154 [08:40<03:30,  4.57s/it]
#
#
#
# Extracting and saving tables:  71%|███████   | 109/154 [08:46<03:47,  5.05s/it]
#
#
#
# Extracting and saving tables:  71%|███████▏  | 110/154 [08:55<04:40,  6.38s/it]
#
#
#
# Extracting and saving tables:  72%|███████▏  | 111/154 [08:59<03:53,  5.42s/it]
#
#
#
# Extracting and saving tables:  73%|███████▎  | 112/154 [09:02<03:19,  4.74s/it]
#
#
#
# Extracting and saving tables:  73%|███████▎  | 113/154 [09:05<02:55,  4.27s/it]
#
#
#
# Extracting and saving tables:  74%|███████▍  | 114/154 [09:08<02:38,  3.95s/it]
#
#
#
# Extracting and saving tables:  75%|███████▍  | 115/154 [09:11<02:23,  3.69s/it]
#
#
#
# Extracting and saving tables:  75%|███████▌  | 116/154 [09:20<03:23,  5.36s/it]
#
#
#
# Extracting and saving tables:  76%|███████▌  | 117/154 [09:24<02:52,  4.67s/it]
#
#
#
# Extracting and saving tables:  77%|███████▋  | 118/154 [09:33<03:38,  6.06s/it]
#
#
#
# Extracting and saving tables:  77%|███████▋  | 119/154 [09:36<03:01,  5.18s/it]
#
#
#
# Extracting and saving tables:  78%|███████▊  | 120/154 [09:39<02:35,  4.57s/it]
#
#
#
# Extracting and saving tables:  79%|███████▊  | 121/154 [09:51<03:48,  6.91s/it]
#
#
#
# Extracting and saving tables:  79%|███████▉  | 122/154 [09:58<03:33,  6.68s/it]
#
#
#
# Extracting and saving tables:  80%|███████▉  | 123/154 [10:07<03:50,  7.45s/it]
#
#
#
# Extracting and saving tables:  81%|████████  | 124/154 [10:16<04:01,  8.05s/it]
#
#
#
# Extracting and saving tables:  81%|████████  | 125/154 [10:19<03:10,  6.56s/it]
#
#
#
# Extracting and saving tables:  82%|████████▏ | 126/154 [10:26<03:00,  6.44s/it]
#
#
#
# Extracting and saving tables:  82%|████████▏ | 127/154 [10:32<02:51,  6.34s/it]
#
#
#
# Extracting and saving tables:  83%|████████▎ | 128/154 [10:41<03:08,  7.26s/it]
#
#
#
# Extracting and saving tables:  84%|████████▍ | 129/154 [10:47<02:53,  6.93s/it]
#
#
#
# Extracting and saving tables:  84%|████████▍ | 130/154 [10:57<03:03,  7.66s/it]
#
#
#
# Extracting and saving tables:  85%|████████▌ | 131/154 [11:00<02:24,  6.29s/it]
#
#
#
# Extracting and saving tables:  86%|████████▌ | 132/154 [11:06<02:17,  6.25s/it]
#
#
#
# Extracting and saving tables:  86%|████████▋ | 133/154 [11:12<02:10,  6.24s/it]
#
#
#
# Extracting and saving tables:  87%|████████▋ | 134/154 [11:21<02:22,  7.11s/it]
#
#
#
# Extracting and saving tables:  88%|████████▊ | 135/154 [11:24<01:52,  5.91s/it]
#
#
#
# Extracting and saving tables:  88%|████████▊ | 136/154 [11:31<01:50,  6.12s/it]
#
#
#
# Extracting and saving tables:  89%|████████▉ | 137/154 [11:40<02:00,  7.11s/it]
#
#
#
# Extracting and saving tables:  90%|████████▉ | 138/154 [11:43<01:34,  5.91s/it]
#
#
#
# Extracting and saving tables:  90%|█████████ | 139/154 [11:50<01:29,  6.00s/it]
#
#
#
# Extracting and saving tables:  91%|█████████ | 140/154 [12:02<01:52,  8.04s/it]
#
#
#
# Extracting and saving tables:  92%|█████████▏| 141/154 [12:06<01:25,  6.56s/it]
#
#
#
# Extracting and saving tables:  92%|█████████▏| 142/154 [12:12<01:18,  6.50s/it]
#
#
#
# Extracting and saving tables:  93%|█████████▎| 143/154 [12:18<01:10,  6.39s/it]
#
#
#
# Extracting and saving tables:  94%|█████████▎| 144/154 [12:24<01:03,  6.33s/it]
#
#
#
# Extracting and saving tables:  94%|█████████▍| 145/154 [12:34<01:05,  7.31s/it]
#
#
#
# Extracting and saving tables:  95%|█████████▍| 146/154 [12:43<01:03,  7.95s/it]
#
#
#
# Extracting and saving tables:  95%|█████████▌| 147/154 [12:49<00:51,  7.41s/it]
#
#
#
# Extracting and saving tables:  96%|█████████▌| 148/154 [12:56<00:42,  7.04s/it]
#
#
#
# Extracting and saving tables:  97%|█████████▋| 149/154 [13:02<00:33,  6.78s/it]
#
#
#
# Extracting and saving tables:  97%|█████████▋| 150/154 [13:05<00:22,  5.63s/it]
#
#
#
# Extracting and saving tables:  98%|█████████▊| 151/154 [13:08<00:14,  4.88s/it]
#
#
#
# Extracting and saving tables:  99%|█████████▊| 152/154 [13:11<00:08,  4.38s/it]
#
#
#
# Extracting and saving tables:  99%|█████████▉| 153/154 [13:14<00:04,  4.02s/it]
#
#
#
# Extracting and saving tables: 100%|██████████| 154/154 [13:17<00:00,  5.18s/it]

# %%
# !ls $config.EXTRACTION_FOLDER
# Out:
# 2015_BASF_Report_page100_1.csv	2015_BASF_Report_page233_3.csv
# 2015_BASF_Report_page101_1.csv	2015_BASF_Report_page234_1.csv
# 2015_BASF_Report_page102_1.csv	2015_BASF_Report_page235_1.csv
# 2015_BASF_Report_page103_1.csv	2015_BASF_Report_page235_2.csv
# 2015_BASF_Report_page103_2.csv	2015_BASF_Report_page236_1.csv
# 2015_BASF_Report_page105_1.csv	2015_BASF_Report_page236_2.csv
# 2015_BASF_Report_page106_1.csv	2015_BASF_Report_page236_3.csv
# 2015_BASF_Report_page108_1.csv	2015_BASF_Report_page236_4.csv
# 2015_BASF_Report_page110_1.csv	2015_BASF_Report_page237_1.csv
# 2015_BASF_Report_page114_1.csv	2015_BASF_Report_page241_1.csv
# 2015_BASF_Report_page116_1.csv	2015_BASF_Report_page241_2.csv
# 2015_BASF_Report_page117_1.csv	2015_BASF_Report_page242_1.csv
# 2015_BASF_Report_page117_2.csv	2015_BASF_Report_page242_2.csv
# 2015_BASF_Report_page119_1.csv	2015_BASF_Report_page243_1.csv
# 2015_BASF_Report_page122_1.csv	2015_BASF_Report_page243_2.csv
# 2015_BASF_Report_page124_1.csv	2015_BASF_Report_page244_1.csv
# 2015_BASF_Report_page124_2.csv	2015_BASF_Report_page244_2.csv
# 2015_BASF_Report_page124_3.csv	2015_BASF_Report_page244_3.csv
# 2015_BASF_Report_page126_1.csv	2015_BASF_Report_page245_1.csv
# 2015_BASF_Report_page127_1.csv	2015_BASF_Report_page245_2.csv
# 2015_BASF_Report_page128_1.csv	2015_BASF_Report_page245_3.csv
# 2015_BASF_Report_page129_1.csv	2015_BASF_Report_page246_1.csv
# 2015_BASF_Report_page137_1.csv	2015_BASF_Report_page246_2.csv
# 2015_BASF_Report_page137_2.csv	2015_BASF_Report_page247_1.csv
# 2015_BASF_Report_page139_1.csv	2015_BASF_Report_page247_2.csv
# 2015_BASF_Report_page139_2.csv	2015_BASF_Report_page248_1.csv
# 2015_BASF_Report_page141_1.csv	2015_BASF_Report_page248_2.csv
# 2015_BASF_Report_page141_2.csv	2015_BASF_Report_page249_1.csv
# 2015_BASF_Report_page145_1.csv	2015_BASF_Report_page253_1.csv
# 2015_BASF_Report_page152_1.csv	2015_BASF_Report_page259_1.csv
# 2015_BASF_Report_page158_1.csv	2015_BASF_Report_page260_1.csv
# 2015_BASF_Report_page159_1.csv	2015_BASF_Report_page262_1.csv
# 2015_BASF_Report_page160_1.csv	2015_BASF_Report_page2_1.csv
# 2015_BASF_Report_page160_2.csv	2015_BASF_Report_page2_2.csv
# 2015_BASF_Report_page161_1.csv	2015_BASF_Report_page2_3.csv
# 2015_BASF_Report_page161_2.csv	2015_BASF_Report_page2_4.csv
# 2015_BASF_Report_page163_1.csv	2015_BASF_Report_page2_5.csv
# 2015_BASF_Report_page169_1.csv	2015_BASF_Report_page30_1.csv
# 2015_BASF_Report_page171_1.csv	2015_BASF_Report_page34_1.csv
# 2015_BASF_Report_page173_1.csv	2015_BASF_Report_page34_2.csv
# 2015_BASF_Report_page174_1.csv	2015_BASF_Report_page37_1.csv
# 2015_BASF_Report_page174_2.csv	2015_BASF_Report_page37_2.csv
# 2015_BASF_Report_page175_1.csv	2015_BASF_Report_page3_1.csv
# 2015_BASF_Report_page175_2.csv	2015_BASF_Report_page3_2.csv
# 2015_BASF_Report_page176_1.csv	2015_BASF_Report_page3_3.csv
# 2015_BASF_Report_page177_1.csv	2015_BASF_Report_page40_1.csv
# 2015_BASF_Report_page182_1.csv	2015_BASF_Report_page44_1.csv
# 2015_BASF_Report_page182_2.csv	2015_BASF_Report_page44_2.csv
# 2015_BASF_Report_page183_1.csv	2015_BASF_Report_page45_1.csv
# 2015_BASF_Report_page189_1.csv	2015_BASF_Report_page45_2.csv
# 2015_BASF_Report_page189_2.csv	2015_BASF_Report_page45_3.csv
# 2015_BASF_Report_page190_1.csv	2015_BASF_Report_page46_1.csv
# 2015_BASF_Report_page190_2.csv	2015_BASF_Report_page48_1.csv
# 2015_BASF_Report_page191_1.csv	2015_BASF_Report_page4_1.csv
# 2015_BASF_Report_page191_2.csv	2015_BASF_Report_page4_2.csv
# 2015_BASF_Report_page193_1.csv	2015_BASF_Report_page4_3.csv
# 2015_BASF_Report_page194_1.csv	2015_BASF_Report_page50_1.csv
# 2015_BASF_Report_page194_2.csv	2015_BASF_Report_page53_1.csv
# 2015_BASF_Report_page195_1.csv	2015_BASF_Report_page55_1.csv
# 2015_BASF_Report_page196_1.csv	2015_BASF_Report_page55_2.csv
# 2015_BASF_Report_page196_2.csv	2015_BASF_Report_page57_1.csv
# 2015_BASF_Report_page196_3.csv	2015_BASF_Report_page58_1.csv
# 2015_BASF_Report_page197_1.csv	2015_BASF_Report_page58_2.csv
# 2015_BASF_Report_page197_2.csv	2015_BASF_Report_page58_3.csv
# 2015_BASF_Report_page198_1.csv	2015_BASF_Report_page59_1.csv
# 2015_BASF_Report_page198_2.csv	2015_BASF_Report_page5_1.csv
# 2015_BASF_Report_page199_1.csv	2015_BASF_Report_page61_1.csv
# 2015_BASF_Report_page19_1.csv	2015_BASF_Report_page62_1.csv
# 2015_BASF_Report_page200_1.csv	2015_BASF_Report_page62_2.csv
# 2015_BASF_Report_page201_1.csv	2015_BASF_Report_page64_1.csv
# 2015_BASF_Report_page202_1.csv	2015_BASF_Report_page64_2.csv
# 2015_BASF_Report_page203_1.csv	2015_BASF_Report_page65_1.csv
# 2015_BASF_Report_page203_2.csv	2015_BASF_Report_page65_2.csv
# 2015_BASF_Report_page204_1.csv	2015_BASF_Report_page66_1.csv
# 2015_BASF_Report_page204_2.csv	2015_BASF_Report_page67_1.csv
# 2015_BASF_Report_page205_1.csv	2015_BASF_Report_page68_1.csv
# 2015_BASF_Report_page205_2.csv	2015_BASF_Report_page68_2.csv
# 2015_BASF_Report_page205_3.csv	2015_BASF_Report_page68_3.csv
# 2015_BASF_Report_page206_1.csv	2015_BASF_Report_page69_1.csv
# 2015_BASF_Report_page207_1.csv	2015_BASF_Report_page69_2.csv
# 2015_BASF_Report_page208_1.csv	2015_BASF_Report_page69_3.csv
# 2015_BASF_Report_page209_1.csv	2015_BASF_Report_page70_1.csv
# 2015_BASF_Report_page210_1.csv	2015_BASF_Report_page71_1.csv
# 2015_BASF_Report_page211_1.csv	2015_BASF_Report_page72_1.csv
# 2015_BASF_Report_page211_2.csv	2015_BASF_Report_page73_1.csv
# 2015_BASF_Report_page211_3.csv	2015_BASF_Report_page74_1.csv
# 2015_BASF_Report_page212_1.csv	2015_BASF_Report_page74_2.csv
# 2015_BASF_Report_page213_1.csv	2015_BASF_Report_page75_1.csv
# 2015_BASF_Report_page213_2.csv	2015_BASF_Report_page75_2.csv
# 2015_BASF_Report_page213_3.csv	2015_BASF_Report_page76_1.csv
# 2015_BASF_Report_page214_1.csv	2015_BASF_Report_page77_1.csv
# 2015_BASF_Report_page215_1.csv	2015_BASF_Report_page77_2.csv
# 2015_BASF_Report_page217_1.csv	2015_BASF_Report_page77_3.csv
# 2015_BASF_Report_page217_2.csv	2015_BASF_Report_page78_1.csv
# 2015_BASF_Report_page217_3.csv	2015_BASF_Report_page78_2.csv
# 2015_BASF_Report_page217_4.csv	2015_BASF_Report_page78_3.csv
# 2015_BASF_Report_page218_1.csv	2015_BASF_Report_page78_4.csv
# 2015_BASF_Report_page218_2.csv	2015_BASF_Report_page79_1.csv
# 2015_BASF_Report_page219_1.csv	2015_BASF_Report_page80_1.csv
# 2015_BASF_Report_page219_2.csv	2015_BASF_Report_page80_2.csv
# 2015_BASF_Report_page219_3.csv	2015_BASF_Report_page81_1.csv
# 2015_BASF_Report_page220_1.csv	2015_BASF_Report_page82_1.csv
# 2015_BASF_Report_page220_2.csv	2015_BASF_Report_page83_1.csv
# 2015_BASF_Report_page220_3.csv	2015_BASF_Report_page84_1.csv
# 2015_BASF_Report_page221_1.csv	2015_BASF_Report_page85_1.csv
# 2015_BASF_Report_page222_1.csv	2015_BASF_Report_page85_2.csv
# 2015_BASF_Report_page222_2.csv	2015_BASF_Report_page86_1.csv
# 2015_BASF_Report_page223_1.csv	2015_BASF_Report_page86_2.csv
# 2015_BASF_Report_page223_2.csv	2015_BASF_Report_page87_1.csv
# 2015_BASF_Report_page224_1.csv	2015_BASF_Report_page87_2.csv
# 2015_BASF_Report_page224_2.csv	2015_BASF_Report_page88_1.csv
# 2015_BASF_Report_page224_3.csv	2015_BASF_Report_page89_1.csv
# 2015_BASF_Report_page225_1.csv	2015_BASF_Report_page90_1.csv
# 2015_BASF_Report_page225_2.csv	2015_BASF_Report_page91_1.csv
# 2015_BASF_Report_page226_1.csv	2015_BASF_Report_page91_2.csv
# 2015_BASF_Report_page226_2.csv	2015_BASF_Report_page92_1.csv
# 2015_BASF_Report_page226_3.csv	2015_BASF_Report_page93_1.csv
# 2015_BASF_Report_page227_1.csv	2015_BASF_Report_page93_2.csv
# 2015_BASF_Report_page228_1.csv	2015_BASF_Report_page94_1.csv
# 2015_BASF_Report_page228_2.csv	2015_BASF_Report_page94_2.csv
# 2015_BASF_Report_page229_1.csv	2015_BASF_Report_page95_1.csv
# 2015_BASF_Report_page229_2.csv	2015_BASF_Report_page96_1.csv
# 2015_BASF_Report_page230_1.csv	2015_BASF_Report_page98_1.csv
# 2015_BASF_Report_page230_2.csv	2015_BASF_Report_page99_1.csv
# 2015_BASF_Report_page230_3.csv	2015_BASF_Report_page99_2.csv
# 2015_BASF_Report_page231_1.csv	cez-en-annual-report-2018_page7_1.csv
# 2015_BASF_Report_page232_1.csv	cez-en-annual-report-2018_page7_2.csv
# 2015_BASF_Report_page232_2.csv	cez-en-annual-report-2018_page7_3.csv
# 2015_BASF_Report_page233_1.csv	cez-en-annual-report-2018_page8_1.csv
# 2015_BASF_Report_page233_2.csv	table_meta.json

# %% [markdown]
# Notice that there is a `table_meta.json` which contains the corresponding table csv files for each page of each pdf file.

# %% [markdown]
# # 2. Table Curation

# %% [markdown]
#  We focus on the tables extracted from `2015_BASF_Report.pdf` and will be using Allyson's annotations on this report.

# %%
from esg_data_pipeline import TableCurator

# %%
tb_cur = TableCurator(neg_pos_ratio=1, create_neg_samples=True)

# %%
tb_cur.run(config.EXTRACTION_FOLDER, config.ANNOTATION_FOLDER, config.CURATION_FOLDER)
# Out:
# 2020-07-23 22:19:18,034 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 21.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,036 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 22.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,037 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 23.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,038 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 24.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,039 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 21.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,040 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 22.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,041 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 23.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,043 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 24.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,054 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 61.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,056 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 62.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,057 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 63.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,058 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 64.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,060 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 65.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,061 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 66.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,062 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 61.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,063 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 62.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,064 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 63.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,065 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 64.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,066 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 65.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,068 — esg_data_pipeline.components.table_curator — WARNING —create_pos_examples:99 — 66.0 is not a valid kpi id. Skipping this example...
# 2020-07-23 22:19:18,073 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,074 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,075 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,076 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,076 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,077 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,078 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,079 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,080 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,081 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,082 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,083 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,084 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,085 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,086 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,087 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,087 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,089 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,090 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,091 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,091 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,092 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,093 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,094 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,095 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,096 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,097 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,098 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,098 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,099 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,100 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,101 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,102 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,103 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,104 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,105 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,105 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,106 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,107 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,108 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,109 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,110 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,111 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,112 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,113 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,114 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,115 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,115 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,116 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,117 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,118 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,119 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,120 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,121 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,122 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,123 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,124 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,124 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,125 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,126 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,127 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,128 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,129 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,130 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,131 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,132 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,133 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,133 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,134 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,135 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,136 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,137 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,138 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,139 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,140 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,141 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — BASF_Report_2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,142 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Wintershall-Dea_Sustainability_Report_2019.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,143 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Wintershall-Dea_Sustainability_Report_2019.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,144 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Wintershall-Dea_Sustainability_Report_2019.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,145 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Wintershall-Dea_Sustainability_Report_2019.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,146 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Wintershall-Dea_Sustainability_Report_2019.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,147 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Wintershall-Dea_Sustainability_Report_2019.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,148 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,148 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,149 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,150 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,151 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,152 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,153 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,154 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,155 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,156 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,157 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,158 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,159 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,160 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — annual 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,160 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Rosneft_CSR18_EN_Book sustainabilitz 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,161 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Rosneft_CSR18_EN_Book sustainabilitz 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,162 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Rosneft_CSR18_EN_Book sustainabilitz 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,163 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Rosneft_CSR18_EN_Book sustainabilitz 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,164 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Rosneft_CSR18_EN_Book sustainabilitz 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,165 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Rosneft_CSR18_EN_Book sustainabilitz 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,166 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Rosneft_CSR18_EN_Book sustainabilitz 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,167 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Rosneft_CSR18_EN_Book sustainabilitz 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,168 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Rosneft_CSR18_EN_Book sustainabilitz 2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,169 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — RN_SR2018_eng_web_1 sustainability 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,170 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — RN_SR2018_eng_web_1 sustainability 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,170 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — RN_SR2018_eng_web_1 sustainability 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,171 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — RN_SR2018_eng_web_1 sustainability 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,172 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — RN_SR2018_eng_web_1 sustainability 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,173 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — RN_SR2018_eng_web_1 sustainability 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,174 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — RN_SR2018_eng_web_1 sustainability 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,175 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — RN_SR2018_eng_web_1 sustainability 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,176 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — RN_SR2018_eng_web_1 sustainability 2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,177 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,178 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,179 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,180 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,180 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,181 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,182 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,183 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,184 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,185 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,186 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,187 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — Aker-BP-Annual-report-2018.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,188 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,189 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,190 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,191 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,192 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,193 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,194 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,195 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,196 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,196 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,197 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,198 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2017.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,199 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,200 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,201 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,202 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,203 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2016.pdf does not exist in table_meta.json
# 2020-07-23 22:19:18,204 — esg_data_pipeline.components.table_curator — WARNING —process_single_annotation_file:262 — AKERBP-Annual-Report-2016.pdf does not exist in table_meta.json

# %% [markdown]
# Most of the warnings are just pdfs which do not exist in `table_meta.json`, in other words do not exist in the initial pdfs folder. Next, we will see that the curation folder will have a csv which shows the curated data.

# %%
# !ls $config.CURATION_FOLDER
# Out:
# esg_table_dataset.csv

# %%
import pandas as pd
df = pd.read_csv(config.CURATION_FOLDER / "esg_table_dataset.csv", index_col=0)

# %%
df
# Out:
#     Company  Year                                           Question                                      Answer                  Table_filename  Label
# 0   BASF SE  2015  What is the total volume of crude oil liquid p...                                         NaN  2015_BASF_Report_page208_1.csv      0
# 1   BASF SE  2015  What is the total volume of crude oil liquid p...                  41 million barrels (MMbbl)  2015_BASF_Report_page242_1.csv      1
# 2   BASF SE  2015  What is the total volume of natural gas produc...                                         NaN   2015_BASF_Report_page30_1.csv      0
# 3   BASF SE  2015  What is the total volume of natural gas produc...      632 billion standard cubic feet (BSCF)  2015_BASF_Report_page242_2.csv      1
# 4   BASF SE  2014  What is the total volume of crude oil liquid p...                                         NaN   2015_BASF_Report_page93_2.csv      0
# 5   BASF SE  2014  What is the total volume of crude oil liquid p...                  31 million barrels (MMbbl)  2015_BASF_Report_page243_1.csv      1
# 6   BASF SE  2014  What is the total volume of natural gas produc...                                         NaN  2015_BASF_Report_page203_2.csv      0
# 7   BASF SE  2014  What is the total volume of natural gas produc...      590 billion standard cubic feet (BSCF)  2015_BASF_Report_page243_2.csv      1
# 8   BASF SE  2015  What is the total amount of energy indirect gr...                                         NaN    2015_BASF_Report_page5_1.csv      0
# 9   BASF SE  2015  What is the total amount of energy indirect gr...  3,795 1,000 metric tons of CO2 equivalents  2015_BASF_Report_page122_1.csv      1
# 10  BASF SE  2014  What is the total amount of energy indirect gr...                                         NaN   2015_BASF_Report_page59_1.csv      0
# 11  BASF SE  2014  What is the total amount of energy indirect gr...  3,911 1,000 metric tons of CO2 equivalents  2015_BASF_Report_page122_1.csv      1
